# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Bader Alabidi**
#
# Data Science

# %% [markdown]
# *I am interested in data science because  this is the best work in The twenty-first century*

# %% [markdown]
# ### in cell 5 i will use the print code ###

# %%
print("Hello world")
# Out:
# Hello world

# %% [markdown]
# this is the numbered list
# 1. Data analysis
# 2. data mining
# 3. data science
# this is the bulleted list
# - Data analysis
# - data mining
# - data science
#
# this is the picture
# ![%D9%A2%D9%A0%D9%A2%D9%A1%D9%A0%D9%A9%D9%A2%D9%A0_%D9%A1%D9%A6%D9%A1%D9%A0%D9%A4%D9%A3.jpg](attachment:%D9%A2%D9%A0%D9%A2%D9%A1%D9%A0%D9%A9%D9%A2%D9%A0_%D9%A1%D9%A6%D9%A1%D9%A0%D9%A4%D9%A3.jpg)
